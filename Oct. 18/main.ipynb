# %%
import pandas as pd
import numpy as np

# %%
stop_time = pd.read_csv('stop_times_cleaned.csv')
stop_time.head()
# Out:
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_31176\3979044263.py:1: DtypeWarning: Columns (2,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   stop_time = pd.read_csv('stop_times_cleaned.csv')
#    Unnamed: 0                                 trip_id stop_id arrival_time  \
# 0           0  ASP22GEN-1037-Sunday-00_000600_1..S03R     101     00:06:00
# 1           1  ASP22GEN-1037-Sunday-00_000600_1..S03R     103     00:07:30
# 2           2  ASP22GEN-1037-Sunday-00_000600_1..S03R     104     00:09:00
# 3           3  ASP22GEN-1037-Sunday-00_000600_1..S03R     106     00:10:30
# 4           4  ASP22GEN-1037-Sunday-00_000600_1..S03R     107     00:12:00
#
#   departure_time  stop_sequence               service_id  sub_trip_id  \
# 0       00:06:00              1  ASP22GEN-1037-Sunday-00          600
# 1       00:07:30              2  ASP22GEN-1037-Sunday-00          600
# 2       00:09:00              3  ASP22GEN-1037-Sunday-00          600
# ...

# %%
line_1 = stop_time.loc[stop_time.train==1]

# %%
#line_1['arrival_time'] = pd.to_datetime(line_1['arrival_time'])
line_1['hour'] = line_1['arrival_time'].apply(lambda x: str(x)[:2])
line_1.head()
# Out:
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_31176\3154184073.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   line_1['hour'] = line_1['arrival_time'].apply(lambda x: str(x)[:2])
#    Unnamed: 0                                 trip_id stop_id arrival_time  \
# 0           0  ASP22GEN-1037-Sunday-00_000600_1..S03R     101     00:06:00
# 1           1  ASP22GEN-1037-Sunday-00_000600_1..S03R     103     00:07:30
# 2           2  ASP22GEN-1037-Sunday-00_000600_1..S03R     104     00:09:00
# 3           3  ASP22GEN-1037-Sunday-00_000600_1..S03R     106     00:10:30
# 4           4  ASP22GEN-1037-Sunday-00_000600_1..S03R     107     00:12:00
#
#   departure_time  stop_sequence               service_id  sub_trip_id  \
# ...

# %%
line_1.to_csv('line_1.csv')
